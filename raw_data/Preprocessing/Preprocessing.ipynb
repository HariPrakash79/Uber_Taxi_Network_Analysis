# %%
import pandas as pd
import glob
import os

# ✅ Make sure the output folder exists
os.makedirs('D:/MSDS/Network Science/project/green_combined_data_sampled/', exist_ok=True)

# Get all green taxi files (2014–2024)
file_list = sorted(glob.glob('D:/MSDS/Network Science/project/raw_data/green_tripdata_*.parquet'))

print(f"Found {len(file_list)} green taxi files to process.")

# Group into batches of 4 files (for every 4 months)
batch_size = 4
batches = [file_list[i:i + batch_size] for i in range(0, len(file_list), batch_size)]

for batch_num, batch_files in enumerate(batches, start=1):
    print(f"\n🔄 Processing Green Taxi batch {batch_num}:")
    batch_dfs = []
    
    for file in batch_files:
        try:
            needed_columns = ['VendorID', 'lpep_pickup_datetime', 'lpep_dropoff_datetime',
                              'PULocationID', 'DOLocationID',
                              'trip_distance', 'fare_amount', 'tip_amount', 'total_amount']
            
            # Read the full file, then subset columns
            df = pd.read_parquet(file)
            available_columns = [col for col in needed_columns if col in df.columns]
            df = df[available_columns]
            
            # Random sample of 10,000 rows
            df_sampled = df.sample(n=10000, random_state=42)
            
            # Drop rows with missing PU/DO locations
            df_cleaned = df_sampled.dropna(subset=['PULocationID', 'DOLocationID'])
            
            batch_dfs.append(df_cleaned)
            print(f" - Sampled and cleaned {file} ({df_cleaned.shape[0]} rows kept)")

        except Exception as e:
            print(f"❗ Error reading/cleaning {file}: {e}")
    
    if batch_dfs:
        # Combine the 4 files into one DataFrame
        combined_df = pd.concat(batch_dfs, ignore_index=True)
        
        # Extract the start and end month/year for naming
        start_file = os.path.basename(batch_files[0])
        end_file = os.path.basename(batch_files[-1])
        
        start_period = start_file.replace('green_tripdata_', '').replace('.parquet', '')
        end_period = end_file.replace('green_tripdata_', '').replace('.parquet', '')
        
        # Save combined CSV file
        output_file = f'D:/MSDS/Network Science/project/green_combined_data_sampled/green_tripdata_{start_period}_to_{end_period}_sampled.csv'
        
        combined_df.to_csv(output_file, index=False)
        print(f"💾 Saved sampled Green Taxi CSV file: {output_file}")
    else:
        print(f"⚠️ No data to save for Green Taxi batch {batch_num}.")
# Out:
# Found 121 green taxi files to process.
#
# 🔄 Processing Green Taxi batch 1:
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\green_tripdata_2014-01.parquet (10000 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\green_tripdata_2014-02.parquet (10000 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\green_tripdata_2014-03.parquet (10000 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\green_tripdata_2014-04.parquet (10000 rows kept)
# 💾 Saved sampled Green Taxi CSV file: D:/MSDS/Network Science/project/green_combined_data_sampled/green_tripdata_2014-01_to_2014-04_sampled.csv
#
# 🔄 Processing Green Taxi batch 2:
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\green_tripdata_2014-05.parquet (10000 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\green_tripdata_2014-06.parquet (10000 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\green_tripdata_2014-07.parquet (10000 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\green_tripdata_2014-08.parquet (10000 rows kept)
# 💾 Saved sampled Green Taxi CSV file: D:/MSDS/Network Science/project/green_combined_data_sampled/green_tripdata_2014-05_to_2014-08_sampled.csv
#
# 🔄 Processing Green Taxi batch 3:
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\green_tripdata_2014-09.parquet (10000 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\green_tripdata_2014-10.parquet (10000 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\green_tripdata_2014-11.parquet (10000 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\green_tripdata_2014-12.parquet (10000 rows kept)
# 💾 Saved sampled Green Taxi CSV file: D:/MSDS/Network Science/project/green_combined_data_sampled/green_tripdata_2014-09_to_2014-12_sampled.csv
#
# 🔄 Processing Green Taxi batch 4:
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\green_tripdata_2015-01.parquet (10000 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\green_tripdata_2015-02.parquet (10000 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\green_tripdata_2015-03.parquet (10000 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\green_tripdata_2015-04.parquet (10000 rows kept)
# 💾 Saved sampled Green Taxi CSV file: D:/MSDS/Network Science/project/green_combined_data_sampled/green_tripdata_2015-01_to_2015-04_sampled.csv
#
# 🔄 Processing Green Taxi batch 5:
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\green_tripdata_2015-05.parquet (10000 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\green_tripdata_2015-06.parquet (10000 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\green_tripdata_2015-07.parquet (10000 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\green_tripdata_2015-08.parquet (10000 rows kept)
# 💾 Saved sampled Green Taxi CSV file: D:/MSDS/Network Science/project/green_combined_data_sampled/green_tripdata_2015-05_to_2015-08_sampled.csv
#
# 🔄 Processing Green Taxi batch 6:
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\green_tripdata_2015-09.parquet (10000 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\green_tripdata_2015-10.parquet (10000 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\green_tripdata_2015-11.parquet (10000 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\green_tripdata_2015-12.parquet (10000 rows kept)
# 💾 Saved sampled Green Taxi CSV file: D:/MSDS/Network Science/project/green_combined_data_sampled/green_tripdata_2015-09_to_2015-12_sampled.csv
#
# 🔄 Processing Green Taxi batch 7:
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\green_tripdata_2016-01.parquet (10000 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\green_tripdata_2016-02.parquet (10000 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\green_tripdata_2016-03.parquet (10000 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\green_tripdata_2016-04.parquet (10000 rows kept)
# 💾 Saved sampled Green Taxi CSV file: D:/MSDS/Network Science/project/green_combined_data_sampled/green_tripdata_2016-01_to_2016-04_sampled.csv
#
# 🔄 Processing Green Taxi batch 8:
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\green_tripdata_2016-05.parquet (10000 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\green_tripdata_2016-06.parquet (10000 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\green_tripdata_2016-07.parquet (10000 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\green_tripdata_2016-08.parquet (10000 rows kept)
# 💾 Saved sampled Green Taxi CSV file: D:/MSDS/Network Science/project/green_combined_data_sampled/green_tripdata_2016-05_to_2016-08_sampled.csv
#
# 🔄 Processing Green Taxi batch 9:
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\green_tripdata_2016-09.parquet (10000 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\green_tripdata_2016-10.parquet (10000 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\green_tripdata_2016-11.parquet (10000 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\green_tripdata_2016-12.parquet (10000 rows kept)
# 💾 Saved sampled Green Taxi CSV file: D:/MSDS/Network Science/project/green_combined_data_sampled/green_tripdata_2016-09_to_2016-12_sampled.csv
#
# 🔄 Processing Green Taxi batch 10:
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\green_tripdata_2017-01.parquet (10000 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\green_tripdata_2017-02.parquet (10000 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\green_tripdata_2017-03.parquet (10000 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\green_tripdata_2017-04.parquet (10000 rows kept)
# 💾 Saved sampled Green Taxi CSV file: D:/MSDS/Network Science/project/green_combined_data_sampled/green_tripdata_2017-01_to_2017-04_sampled.csv
#
# 🔄 Processing Green Taxi batch 11:
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\green_tripdata_2017-05.parquet (10000 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\green_tripdata_2017-06.parquet (10000 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\green_tripdata_2017-07.parquet (10000 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\green_tripdata_2017-08.parquet (10000 rows kept)
# 💾 Saved sampled Green Taxi CSV file: D:/MSDS/Network Science/project/green_combined_data_sampled/green_tripdata_2017-05_to_2017-08_sampled.csv
#
# 🔄 Processing Green Taxi batch 12:
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\green_tripdata_2017-09.parquet (10000 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\green_tripdata_2017-10.parquet (10000 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\green_tripdata_2017-11.parquet (10000 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\green_tripdata_2017-12.parquet (10000 rows kept)
# 💾 Saved sampled Green Taxi CSV file: D:/MSDS/Network Science/project/green_combined_data_sampled/green_tripdata_2017-09_to_2017-12_sampled.csv
#
# 🔄 Processing Green Taxi batch 13:
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\green_tripdata_2018-01.parquet (10000 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\green_tripdata_2018-02.parquet (10000 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\green_tripdata_2018-03.parquet (10000 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\green_tripdata_2018-04.parquet (10000 rows kept)
# 💾 Saved sampled Green Taxi CSV file: D:/MSDS/Network Science/project/green_combined_data_sampled/green_tripdata_2018-01_to_2018-04_sampled.csv
#
# 🔄 Processing Green Taxi batch 14:
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\green_tripdata_2018-05.parquet (10000 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\green_tripdata_2018-06.parquet (10000 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\green_tripdata_2018-07.parquet (10000 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\green_tripdata_2018-08.parquet (10000 rows kept)
# 💾 Saved sampled Green Taxi CSV file: D:/MSDS/Network Science/project/green_combined_data_sampled/green_tripdata_2018-05_to_2018-08_sampled.csv
#
# 🔄 Processing Green Taxi batch 15:
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\green_tripdata_2018-09.parquet (10000 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\green_tripdata_2018-10.parquet (10000 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\green_tripdata_2018-11.parquet (10000 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\green_tripdata_2018-12.parquet (10000 rows kept)
# 💾 Saved sampled Green Taxi CSV file: D:/MSDS/Network Science/project/green_combined_data_sampled/green_tripdata_2018-09_to_2018-12_sampled.csv
#
# 🔄 Processing Green Taxi batch 16:
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\green_tripdata_2019-01.parquet (10000 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\green_tripdata_2019-02.parquet (10000 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\green_tripdata_2019-03.parquet (10000 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\green_tripdata_2019-04.parquet (10000 rows kept)
# 💾 Saved sampled Green Taxi CSV file: D:/MSDS/Network Science/project/green_combined_data_sampled/green_tripdata_2019-01_to_2019-04_sampled.csv
#
# 🔄 Processing Green Taxi batch 17:
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\green_tripdata_2019-05.parquet (10000 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\green_tripdata_2019-06.parquet (10000 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\green_tripdata_2019-07.parquet (10000 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\green_tripdata_2019-08.parquet (10000 rows kept)
# 💾 Saved sampled Green Taxi CSV file: D:/MSDS/Network Science/project/green_combined_data_sampled/green_tripdata_2019-05_to_2019-08_sampled.csv
#
# 🔄 Processing Green Taxi batch 18:
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\green_tripdata_2019-09.parquet (10000 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\green_tripdata_2019-10.parquet (10000 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\green_tripdata_2019-11.parquet (10000 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\green_tripdata_2019-12.parquet (10000 rows kept)
# 💾 Saved sampled Green Taxi CSV file: D:/MSDS/Network Science/project/green_combined_data_sampled/green_tripdata_2019-09_to_2019-12_sampled.csv
#
# 🔄 Processing Green Taxi batch 19:
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\green_tripdata_2020-01.parquet (10000 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\green_tripdata_2020-02.parquet (10000 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\green_tripdata_2020-03.parquet (10000 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\green_tripdata_2020-04.parquet (10000 rows kept)
# 💾 Saved sampled Green Taxi CSV file: D:/MSDS/Network Science/project/green_combined_data_sampled/green_tripdata_2020-01_to_2020-04_sampled.csv
#
# 🔄 Processing Green Taxi batch 20:
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\green_tripdata_2020-05.parquet (10000 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\green_tripdata_2020-06.parquet (10000 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\green_tripdata_2020-07.parquet (10000 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\green_tripdata_2020-08.parquet (10000 rows kept)
# 💾 Saved sampled Green Taxi CSV file: D:/MSDS/Network Science/project/green_combined_data_sampled/green_tripdata_2020-05_to_2020-08_sampled.csv
#
# 🔄 Processing Green Taxi batch 21:
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\green_tripdata_2020-09.parquet (10000 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\green_tripdata_2020-10.parquet (10000 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\green_tripdata_2020-11.parquet (10000 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\green_tripdata_2020-12.parquet (10000 rows kept)
# 💾 Saved sampled Green Taxi CSV file: D:/MSDS/Network Science/project/green_combined_data_sampled/green_tripdata_2020-09_to_2020-12_sampled.csv
#
# 🔄 Processing Green Taxi batch 22:
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\green_tripdata_2021-01.parquet (10000 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\green_tripdata_2021-02.parquet (10000 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\green_tripdata_2021-03.parquet (10000 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\green_tripdata_2021-04.parquet (10000 rows kept)
# 💾 Saved sampled Green Taxi CSV file: D:/MSDS/Network Science/project/green_combined_data_sampled/green_tripdata_2021-01_to_2021-04_sampled.csv
#
# 🔄 Processing Green Taxi batch 23:
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\green_tripdata_2021-05.parquet (10000 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\green_tripdata_2021-06.parquet (10000 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\green_tripdata_2021-07.parquet (10000 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\green_tripdata_2021-08.parquet (10000 rows kept)
# 💾 Saved sampled Green Taxi CSV file: D:/MSDS/Network Science/project/green_combined_data_sampled/green_tripdata_2021-05_to_2021-08_sampled.csv
#
# 🔄 Processing Green Taxi batch 24:
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\green_tripdata_2021-09.parquet (10000 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\green_tripdata_2021-10.parquet (10000 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\green_tripdata_2021-11.parquet (10000 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\green_tripdata_2021-12.parquet (10000 rows kept)
# 💾 Saved sampled Green Taxi CSV file: D:/MSDS/Network Science/project/green_combined_data_sampled/green_tripdata_2021-09_to_2021-12_sampled.csv
#
# 🔄 Processing Green Taxi batch 25:
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\green_tripdata_2022-01.parquet (10000 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\green_tripdata_2022-02.parquet (10000 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\green_tripdata_2022-03.parquet (10000 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\green_tripdata_2022-04.parquet (10000 rows kept)
# 💾 Saved sampled Green Taxi CSV file: D:/MSDS/Network Science/project/green_combined_data_sampled/green_tripdata_2022-01_to_2022-04_sampled.csv
#
# 🔄 Processing Green Taxi batch 26:
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\green_tripdata_2022-05.parquet (10000 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\green_tripdata_2022-06.parquet (10000 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\green_tripdata_2022-07.parquet (10000 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\green_tripdata_2022-08.parquet (10000 rows kept)
# 💾 Saved sampled Green Taxi CSV file: D:/MSDS/Network Science/project/green_combined_data_sampled/green_tripdata_2022-05_to_2022-08_sampled.csv
#
# 🔄 Processing Green Taxi batch 27:
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\green_tripdata_2022-09.parquet (10000 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\green_tripdata_2022-10.parquet (10000 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\green_tripdata_2022-11.parquet (10000 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\green_tripdata_2022-12.parquet (10000 rows kept)
# 💾 Saved sampled Green Taxi CSV file: D:/MSDS/Network Science/project/green_combined_data_sampled/green_tripdata_2022-09_to_2022-12_sampled.csv
#
# 🔄 Processing Green Taxi batch 28:
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\green_tripdata_2023-01.parquet (10000 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\green_tripdata_2023-02.parquet (10000 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\green_tripdata_2023-03.parquet (10000 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\green_tripdata_2023-04.parquet (10000 rows kept)
# 💾 Saved sampled Green Taxi CSV file: D:/MSDS/Network Science/project/green_combined_data_sampled/green_tripdata_2023-01_to_2023-04_sampled.csv
#
# 🔄 Processing Green Taxi batch 29:
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\green_tripdata_2023-05.parquet (10000 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\green_tripdata_2023-06.parquet (10000 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\green_tripdata_2023-07.parquet (10000 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\green_tripdata_2023-08.parquet (10000 rows kept)
# 💾 Saved sampled Green Taxi CSV file: D:/MSDS/Network Science/project/green_combined_data_sampled/green_tripdata_2023-05_to_2023-08_sampled.csv
#
# 🔄 Processing Green Taxi batch 30:
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\green_tripdata_2023-09.parquet (10000 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\green_tripdata_2023-10.parquet (10000 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\green_tripdata_2023-11.parquet (10000 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\green_tripdata_2023-12.parquet (10000 rows kept)
# 💾 Saved sampled Green Taxi CSV file: D:/MSDS/Network Science/project/green_combined_data_sampled/green_tripdata_2023-09_to_2023-12_sampled.csv
#
# 🔄 Processing Green Taxi batch 31:
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\green_tripdata_2024-01.parquet (10000 rows kept)
# 💾 Saved sampled Green Taxi CSV file: D:/MSDS/Network Science/project/green_combined_data_sampled/green_tripdata_2024-01_to_2024-01_sampled.csv

# %%
import pandas as pd

# Load one Yellow Taxi file (change the path to a file you have)
df = pd.read_parquet('D:/MSDS/Network Science/project/raw_data/yellow_tripdata_2019-01.parquet')

# Show first 5 rows
print(df.head(5))

# Show all columns to see what's available
print("\nColumns in this dataset:")
print(df.columns.tolist())
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         1  2019-01-01 00:46:40   2019-01-01 00:53:20              1.0
# 1         1  2019-01-01 00:59:47   2019-01-01 01:18:59              1.0
# 2         2  2018-12-21 13:48:30   2018-12-21 13:52:40              3.0
# 3         2  2018-11-28 15:52:25   2018-11-28 15:55:45              5.0
# 4         2  2018-11-28 15:56:57   2018-11-28 15:58:33              5.0
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0            1.5         1.0                  N           151           239
# 1            2.6         1.0                  N           239           246
# 2            0.0         1.0                  N           236           236
# 3            0.0         1.0                  N           193           193
# 4            0.0         2.0                  N           193           193
#
#    payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# 0             1          7.0    0.5      0.5        1.65           0.0
# 1             1         14.0    0.5      0.5        1.00           0.0
# 2             1          4.5    0.5      0.5        0.00           0.0
# 3             2          3.5    0.5      0.5        0.00           0.0
# 4             2         52.0    0.0      0.5        0.00           0.0
#
#    improvement_surcharge  total_amount  congestion_surcharge airport_fee
# 0                    0.3          9.95                   NaN        None
# 1                    0.3         16.30                   NaN        None
# 2                    0.3          5.80                   NaN        None
# 3                    0.3          7.55                   NaN        None
# 4                    0.3         55.55                   NaN        None
#
# Columns in this dataset:
# ['VendorID', 'tpep_pickup_datetime', 'tpep_dropoff_datetime', 'passenger_count', 'trip_distance', 'RatecodeID', 'store_and_fwd_flag', 'PULocationID', 'DOLocationID', 'payment_type', 'fare_amount', 'extra', 'mta_tax', 'tip_amount', 'tolls_amount', 'improvement_surcharge', 'total_amount', 'congestion_surcharge', 'airport_fee']

# %%
import pandas as pd
import glob
import os

# ✅ Make sure the output folder exists
os.makedirs('D:/MSDS/Network Science/project/yellow_combined_data_sampled/', exist_ok=True)

# Get all yellow taxi files
file_list = sorted(glob.glob('D:/MSDS/Network Science/project/raw_data/yellow_tripdata_*.parquet'))

print(f"Found {len(file_list)} yellow taxi files to process.")

# Group into batches of 4 files (for every 4 months)
batch_size = 4
batches = [file_list[i:i + batch_size] for i in range(0, len(file_list), batch_size)]

for batch_num, batch_files in enumerate(batches, start=1):
    print(f"\n🔄 Processing Yellow Taxi batch {batch_num}:")
    batch_dfs = []
    
    for file in batch_files:
        try:
            # Extract year from filename
            file_name = os.path.basename(file)
            year_str = file_name.split('_')[2].split('-')[0]
            year = int(year_str)
            
            # Skip files from 2009–2014
            if year < 2015:
                print(f"⚠️ Skipping {file} because it is from {year} (before 2015).")
                continue
            
            needed_columns = ['VendorID', 'tpep_pickup_datetime', 'tpep_dropoff_datetime',
                              'PULocationID', 'DOLocationID',
                              'trip_distance', 'fare_amount', 'tip_amount', 'total_amount']
            
            # Read the full file
            df = pd.read_parquet(file)
            
            # Subset only available needed columns
            available_columns = [col for col in needed_columns if col in df.columns]
            df = df[available_columns]
            
            # Random sample of 10,000 rows
            df_sampled = df.sample(n=10000, random_state=42)
            
            # Drop rows with missing PU/DO locations
            df_cleaned = df_sampled.dropna(subset=['PULocationID', 'DOLocationID'])
            
            batch_dfs.append(df_cleaned)
            print(f" - Sampled and cleaned {file} ({df_cleaned.shape[0]} rows kept)")

        except Exception as e:
            print(f"❗ Error reading/cleaning {file}: {e}")
    
    if batch_dfs:
        # Combine the 4 files into one DataFrame
        combined_df = pd.concat(batch_dfs, ignore_index=True)
        
        # Extract the start and end month/year for naming
        start_file = os.path.basename(batch_files[0])
        end_file = os.path.basename(batch_files[-1])
        
        start_period = start_file.replace('yellow_tripdata_', '').replace('.parquet', '')
        end_period = end_file.replace('yellow_tripdata_', '').replace('.parquet', '')
        
        # Save combined CSV file
        output_file = f'D:/MSDS/Network Science/project/yellow_combined_data_sampled/yellow_tripdata_{start_period}_to_{end_period}_sampled.csv'
        
        combined_df.to_csv(output_file, index=False)
        print(f"💾 Saved sampled Yellow Taxi CSV file: {output_file}")
    else:
        print(f"⚠️ No data to save for Yellow Taxi batch {batch_num}.")
# Out:
# Found 181 yellow taxi files to process.
#
# 🔄 Processing Yellow Taxi batch 1:
# ⚠️ Skipping D:/MSDS/Network Science/project/raw_data\yellow_tripdata_2009-01.parquet because it is from 2009 (before 2015).
# ⚠️ Skipping D:/MSDS/Network Science/project/raw_data\yellow_tripdata_2009-02.parquet because it is from 2009 (before 2015).
# ⚠️ Skipping D:/MSDS/Network Science/project/raw_data\yellow_tripdata_2009-03.parquet because it is from 2009 (before 2015).
# ⚠️ Skipping D:/MSDS/Network Science/project/raw_data\yellow_tripdata_2009-04.parquet because it is from 2009 (before 2015).
# ⚠️ No data to save for Yellow Taxi batch 1.
#
# 🔄 Processing Yellow Taxi batch 2:
# ⚠️ Skipping D:/MSDS/Network Science/project/raw_data\yellow_tripdata_2009-05.parquet because it is from 2009 (before 2015).
# ⚠️ Skipping D:/MSDS/Network Science/project/raw_data\yellow_tripdata_2009-06.parquet because it is from 2009 (before 2015).
# ⚠️ Skipping D:/MSDS/Network Science/project/raw_data\yellow_tripdata_2009-07.parquet because it is from 2009 (before 2015).
# ⚠️ Skipping D:/MSDS/Network Science/project/raw_data\yellow_tripdata_2009-08.parquet because it is from 2009 (before 2015).
# ⚠️ No data to save for Yellow Taxi batch 2.
#
# 🔄 Processing Yellow Taxi batch 3:
# ⚠️ Skipping D:/MSDS/Network Science/project/raw_data\yellow_tripdata_2009-09.parquet because it is from 2009 (before 2015).
# ⚠️ Skipping D:/MSDS/Network Science/project/raw_data\yellow_tripdata_2009-10.parquet because it is from 2009 (before 2015).
# ⚠️ Skipping D:/MSDS/Network Science/project/raw_data\yellow_tripdata_2009-11.parquet because it is from 2009 (before 2015).
# ⚠️ Skipping D:/MSDS/Network Science/project/raw_data\yellow_tripdata_2009-12.parquet because it is from 2009 (before 2015).
# ⚠️ No data to save for Yellow Taxi batch 3.
#
# 🔄 Processing Yellow Taxi batch 4:
# ⚠️ Skipping D:/MSDS/Network Science/project/raw_data\yellow_tripdata_2010-01.parquet because it is from 2010 (before 2015).
# ⚠️ Skipping D:/MSDS/Network Science/project/raw_data\yellow_tripdata_2010-02.parquet because it is from 2010 (before 2015).
# ⚠️ Skipping D:/MSDS/Network Science/project/raw_data\yellow_tripdata_2010-03.parquet because it is from 2010 (before 2015).
# ⚠️ Skipping D:/MSDS/Network Science/project/raw_data\yellow_tripdata_2010-04.parquet because it is from 2010 (before 2015).
# ⚠️ No data to save for Yellow Taxi batch 4.
#
# 🔄 Processing Yellow Taxi batch 5:
# ⚠️ Skipping D:/MSDS/Network Science/project/raw_data\yellow_tripdata_2010-05.parquet because it is from 2010 (before 2015).
# ⚠️ Skipping D:/MSDS/Network Science/project/raw_data\yellow_tripdata_2010-06.parquet because it is from 2010 (before 2015).
# ⚠️ Skipping D:/MSDS/Network Science/project/raw_data\yellow_tripdata_2010-07.parquet because it is from 2010 (before 2015).
# ⚠️ Skipping D:/MSDS/Network Science/project/raw_data\yellow_tripdata_2010-08.parquet because it is from 2010 (before 2015).
# ⚠️ No data to save for Yellow Taxi batch 5.
#
# 🔄 Processing Yellow Taxi batch 6:
# ⚠️ Skipping D:/MSDS/Network Science/project/raw_data\yellow_tripdata_2010-09.parquet because it is from 2010 (before 2015).
# ⚠️ Skipping D:/MSDS/Network Science/project/raw_data\yellow_tripdata_2010-10.parquet because it is from 2010 (before 2015).
# ⚠️ Skipping D:/MSDS/Network Science/project/raw_data\yellow_tripdata_2010-11.parquet because it is from 2010 (before 2015).
# ⚠️ Skipping D:/MSDS/Network Science/project/raw_data\yellow_tripdata_2010-12.parquet because it is from 2010 (before 2015).
# ⚠️ No data to save for Yellow Taxi batch 6.
#
# 🔄 Processing Yellow Taxi batch 7:
# ⚠️ Skipping D:/MSDS/Network Science/project/raw_data\yellow_tripdata_2011-01.parquet because it is from 2011 (before 2015).
# ⚠️ Skipping D:/MSDS/Network Science/project/raw_data\yellow_tripdata_2011-02.parquet because it is from 2011 (before 2015).
# ⚠️ Skipping D:/MSDS/Network Science/project/raw_data\yellow_tripdata_2011-03.parquet because it is from 2011 (before 2015).
# ⚠️ Skipping D:/MSDS/Network Science/project/raw_data\yellow_tripdata_2011-04.parquet because it is from 2011 (before 2015).
# ⚠️ No data to save for Yellow Taxi batch 7.
#
# 🔄 Processing Yellow Taxi batch 8:
# ⚠️ Skipping D:/MSDS/Network Science/project/raw_data\yellow_tripdata_2011-05.parquet because it is from 2011 (before 2015).
# ⚠️ Skipping D:/MSDS/Network Science/project/raw_data\yellow_tripdata_2011-06.parquet because it is from 2011 (before 2015).
# ⚠️ Skipping D:/MSDS/Network Science/project/raw_data\yellow_tripdata_2011-07.parquet because it is from 2011 (before 2015).
# ⚠️ Skipping D:/MSDS/Network Science/project/raw_data\yellow_tripdata_2011-08.parquet because it is from 2011 (before 2015).
# ⚠️ No data to save for Yellow Taxi batch 8.
#
# 🔄 Processing Yellow Taxi batch 9:
# ⚠️ Skipping D:/MSDS/Network Science/project/raw_data\yellow_tripdata_2011-09.parquet because it is from 2011 (before 2015).
# ⚠️ Skipping D:/MSDS/Network Science/project/raw_data\yellow_tripdata_2011-10.parquet because it is from 2011 (before 2015).
# ⚠️ Skipping D:/MSDS/Network Science/project/raw_data\yellow_tripdata_2011-11.parquet because it is from 2011 (before 2015).
# ⚠️ Skipping D:/MSDS/Network Science/project/raw_data\yellow_tripdata_2011-12.parquet because it is from 2011 (before 2015).
# ⚠️ No data to save for Yellow Taxi batch 9.
#
# 🔄 Processing Yellow Taxi batch 10:
# ⚠️ Skipping D:/MSDS/Network Science/project/raw_data\yellow_tripdata_2012-01.parquet because it is from 2012 (before 2015).
# ⚠️ Skipping D:/MSDS/Network Science/project/raw_data\yellow_tripdata_2012-02.parquet because it is from 2012 (before 2015).
# ⚠️ Skipping D:/MSDS/Network Science/project/raw_data\yellow_tripdata_2012-03.parquet because it is from 2012 (before 2015).
# ⚠️ Skipping D:/MSDS/Network Science/project/raw_data\yellow_tripdata_2012-04.parquet because it is from 2012 (before 2015).
# ⚠️ No data to save for Yellow Taxi batch 10.
#
# 🔄 Processing Yellow Taxi batch 11:
# ⚠️ Skipping D:/MSDS/Network Science/project/raw_data\yellow_tripdata_2012-05.parquet because it is from 2012 (before 2015).
# ⚠️ Skipping D:/MSDS/Network Science/project/raw_data\yellow_tripdata_2012-06.parquet because it is from 2012 (before 2015).
# ⚠️ Skipping D:/MSDS/Network Science/project/raw_data\yellow_tripdata_2012-07.parquet because it is from 2012 (before 2015).
# ⚠️ Skipping D:/MSDS/Network Science/project/raw_data\yellow_tripdata_2012-08.parquet because it is from 2012 (before 2015).
# ⚠️ No data to save for Yellow Taxi batch 11.
#
# 🔄 Processing Yellow Taxi batch 12:
# ⚠️ Skipping D:/MSDS/Network Science/project/raw_data\yellow_tripdata_2012-09.parquet because it is from 2012 (before 2015).
# ⚠️ Skipping D:/MSDS/Network Science/project/raw_data\yellow_tripdata_2012-10.parquet because it is from 2012 (before 2015).
# ⚠️ Skipping D:/MSDS/Network Science/project/raw_data\yellow_tripdata_2012-11.parquet because it is from 2012 (before 2015).
# ⚠️ Skipping D:/MSDS/Network Science/project/raw_data\yellow_tripdata_2012-12.parquet because it is from 2012 (before 2015).
# ⚠️ No data to save for Yellow Taxi batch 12.
#
# 🔄 Processing Yellow Taxi batch 13:
# ⚠️ Skipping D:/MSDS/Network Science/project/raw_data\yellow_tripdata_2013-01.parquet because it is from 2013 (before 2015).
# ⚠️ Skipping D:/MSDS/Network Science/project/raw_data\yellow_tripdata_2013-02.parquet because it is from 2013 (before 2015).
# ⚠️ Skipping D:/MSDS/Network Science/project/raw_data\yellow_tripdata_2013-03.parquet because it is from 2013 (before 2015).
# ⚠️ Skipping D:/MSDS/Network Science/project/raw_data\yellow_tripdata_2013-04.parquet because it is from 2013 (before 2015).
# ⚠️ No data to save for Yellow Taxi batch 13.
#
# 🔄 Processing Yellow Taxi batch 14:
# ⚠️ Skipping D:/MSDS/Network Science/project/raw_data\yellow_tripdata_2013-05.parquet because it is from 2013 (before 2015).
# ⚠️ Skipping D:/MSDS/Network Science/project/raw_data\yellow_tripdata_2013-06.parquet because it is from 2013 (before 2015).
# ⚠️ Skipping D:/MSDS/Network Science/project/raw_data\yellow_tripdata_2013-07.parquet because it is from 2013 (before 2015).
# ⚠️ Skipping D:/MSDS/Network Science/project/raw_data\yellow_tripdata_2013-08.parquet because it is from 2013 (before 2015).
# ⚠️ No data to save for Yellow Taxi batch 14.
#
# 🔄 Processing Yellow Taxi batch 15:
# ⚠️ Skipping D:/MSDS/Network Science/project/raw_data\yellow_tripdata_2013-09.parquet because it is from 2013 (before 2015).
# ⚠️ Skipping D:/MSDS/Network Science/project/raw_data\yellow_tripdata_2013-10.parquet because it is from 2013 (before 2015).
# ⚠️ Skipping D:/MSDS/Network Science/project/raw_data\yellow_tripdata_2013-11.parquet because it is from 2013 (before 2015).
# ⚠️ Skipping D:/MSDS/Network Science/project/raw_data\yellow_tripdata_2013-12.parquet because it is from 2013 (before 2015).
# ⚠️ No data to save for Yellow Taxi batch 15.
#
# 🔄 Processing Yellow Taxi batch 16:
# ⚠️ Skipping D:/MSDS/Network Science/project/raw_data\yellow_tripdata_2014-01.parquet because it is from 2014 (before 2015).
# ⚠️ Skipping D:/MSDS/Network Science/project/raw_data\yellow_tripdata_2014-02.parquet because it is from 2014 (before 2015).
# ⚠️ Skipping D:/MSDS/Network Science/project/raw_data\yellow_tripdata_2014-03.parquet because it is from 2014 (before 2015).
# ⚠️ Skipping D:/MSDS/Network Science/project/raw_data\yellow_tripdata_2014-04.parquet because it is from 2014 (before 2015).
# ⚠️ No data to save for Yellow Taxi batch 16.
#
# 🔄 Processing Yellow Taxi batch 17:
# ⚠️ Skipping D:/MSDS/Network Science/project/raw_data\yellow_tripdata_2014-05.parquet because it is from 2014 (before 2015).
# ⚠️ Skipping D:/MSDS/Network Science/project/raw_data\yellow_tripdata_2014-06.parquet because it is from 2014 (before 2015).
# ⚠️ Skipping D:/MSDS/Network Science/project/raw_data\yellow_tripdata_2014-07.parquet because it is from 2014 (before 2015).
# ⚠️ Skipping D:/MSDS/Network Science/project/raw_data\yellow_tripdata_2014-08.parquet because it is from 2014 (before 2015).
# ⚠️ No data to save for Yellow Taxi batch 17.
#
# 🔄 Processing Yellow Taxi batch 18:
# ⚠️ Skipping D:/MSDS/Network Science/project/raw_data\yellow_tripdata_2014-09.parquet because it is from 2014 (before 2015).
# ⚠️ Skipping D:/MSDS/Network Science/project/raw_data\yellow_tripdata_2014-10.parquet because it is from 2014 (before 2015).
# ⚠️ Skipping D:/MSDS/Network Science/project/raw_data\yellow_tripdata_2014-11.parquet because it is from 2014 (before 2015).
# ⚠️ Skipping D:/MSDS/Network Science/project/raw_data\yellow_tripdata_2014-12.parquet because it is from 2014 (before 2015).
# ⚠️ No data to save for Yellow Taxi batch 18.
#
# 🔄 Processing Yellow Taxi batch 19:
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\yellow_tripdata_2015-01.parquet (10000 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\yellow_tripdata_2015-02.parquet (10000 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\yellow_tripdata_2015-03.parquet (10000 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\yellow_tripdata_2015-04.parquet (10000 rows kept)
# 💾 Saved sampled Yellow Taxi CSV file: D:/MSDS/Network Science/project/yellow_combined_data_sampled/yellow_tripdata_2015-01_to_2015-04_sampled.csv
#
# 🔄 Processing Yellow Taxi batch 20:
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\yellow_tripdata_2015-05.parquet (10000 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\yellow_tripdata_2015-06.parquet (10000 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\yellow_tripdata_2015-07.parquet (10000 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\yellow_tripdata_2015-08.parquet (10000 rows kept)
# 💾 Saved sampled Yellow Taxi CSV file: D:/MSDS/Network Science/project/yellow_combined_data_sampled/yellow_tripdata_2015-05_to_2015-08_sampled.csv
#
# 🔄 Processing Yellow Taxi batch 21:
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\yellow_tripdata_2015-09.parquet (10000 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\yellow_tripdata_2015-10.parquet (10000 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\yellow_tripdata_2015-11.parquet (10000 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\yellow_tripdata_2015-12.parquet (10000 rows kept)
# 💾 Saved sampled Yellow Taxi CSV file: D:/MSDS/Network Science/project/yellow_combined_data_sampled/yellow_tripdata_2015-09_to_2015-12_sampled.csv
#
# 🔄 Processing Yellow Taxi batch 22:
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\yellow_tripdata_2016-01.parquet (10000 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\yellow_tripdata_2016-02.parquet (10000 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\yellow_tripdata_2016-03.parquet (10000 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\yellow_tripdata_2016-04.parquet (10000 rows kept)
# 💾 Saved sampled Yellow Taxi CSV file: D:/MSDS/Network Science/project/yellow_combined_data_sampled/yellow_tripdata_2016-01_to_2016-04_sampled.csv
#
# 🔄 Processing Yellow Taxi batch 23:
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\yellow_tripdata_2016-05.parquet (10000 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\yellow_tripdata_2016-06.parquet (10000 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\yellow_tripdata_2016-07.parquet (10000 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\yellow_tripdata_2016-08.parquet (10000 rows kept)
# 💾 Saved sampled Yellow Taxi CSV file: D:/MSDS/Network Science/project/yellow_combined_data_sampled/yellow_tripdata_2016-05_to_2016-08_sampled.csv
#
# 🔄 Processing Yellow Taxi batch 24:
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\yellow_tripdata_2016-09.parquet (10000 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\yellow_tripdata_2016-10.parquet (10000 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\yellow_tripdata_2016-11.parquet (10000 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\yellow_tripdata_2016-12.parquet (10000 rows kept)
# 💾 Saved sampled Yellow Taxi CSV file: D:/MSDS/Network Science/project/yellow_combined_data_sampled/yellow_tripdata_2016-09_to_2016-12_sampled.csv
#
# 🔄 Processing Yellow Taxi batch 25:
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\yellow_tripdata_2017-01.parquet (10000 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\yellow_tripdata_2017-02.parquet (10000 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\yellow_tripdata_2017-03.parquet (10000 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\yellow_tripdata_2017-04.parquet (10000 rows kept)
# 💾 Saved sampled Yellow Taxi CSV file: D:/MSDS/Network Science/project/yellow_combined_data_sampled/yellow_tripdata_2017-01_to_2017-04_sampled.csv
#
# 🔄 Processing Yellow Taxi batch 26:
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\yellow_tripdata_2017-05.parquet (10000 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\yellow_tripdata_2017-06.parquet (10000 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\yellow_tripdata_2017-07.parquet (10000 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\yellow_tripdata_2017-08.parquet (10000 rows kept)
# 💾 Saved sampled Yellow Taxi CSV file: D:/MSDS/Network Science/project/yellow_combined_data_sampled/yellow_tripdata_2017-05_to_2017-08_sampled.csv
#
# 🔄 Processing Yellow Taxi batch 27:
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\yellow_tripdata_2017-09.parquet (10000 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\yellow_tripdata_2017-10.parquet (10000 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\yellow_tripdata_2017-11.parquet (10000 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\yellow_tripdata_2017-12.parquet (10000 rows kept)
# 💾 Saved sampled Yellow Taxi CSV file: D:/MSDS/Network Science/project/yellow_combined_data_sampled/yellow_tripdata_2017-09_to_2017-12_sampled.csv
#
# 🔄 Processing Yellow Taxi batch 28:
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\yellow_tripdata_2018-01.parquet (10000 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\yellow_tripdata_2018-02.parquet (10000 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\yellow_tripdata_2018-03.parquet (10000 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\yellow_tripdata_2018-04.parquet (10000 rows kept)
# 💾 Saved sampled Yellow Taxi CSV file: D:/MSDS/Network Science/project/yellow_combined_data_sampled/yellow_tripdata_2018-01_to_2018-04_sampled.csv
#
# 🔄 Processing Yellow Taxi batch 29:
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\yellow_tripdata_2018-05.parquet (10000 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\yellow_tripdata_2018-06.parquet (10000 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\yellow_tripdata_2018-07.parquet (10000 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\yellow_tripdata_2018-08.parquet (10000 rows kept)
# 💾 Saved sampled Yellow Taxi CSV file: D:/MSDS/Network Science/project/yellow_combined_data_sampled/yellow_tripdata_2018-05_to_2018-08_sampled.csv
#
# 🔄 Processing Yellow Taxi batch 30:
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\yellow_tripdata_2018-09.parquet (10000 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\yellow_tripdata_2018-10.parquet (10000 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\yellow_tripdata_2018-11.parquet (10000 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\yellow_tripdata_2018-12.parquet (10000 rows kept)
# 💾 Saved sampled Yellow Taxi CSV file: D:/MSDS/Network Science/project/yellow_combined_data_sampled/yellow_tripdata_2018-09_to_2018-12_sampled.csv
#
# 🔄 Processing Yellow Taxi batch 31:
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\yellow_tripdata_2019-01.parquet (10000 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\yellow_tripdata_2019-02.parquet (10000 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\yellow_tripdata_2019-03.parquet (10000 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\yellow_tripdata_2019-04.parquet (10000 rows kept)
# 💾 Saved sampled Yellow Taxi CSV file: D:/MSDS/Network Science/project/yellow_combined_data_sampled/yellow_tripdata_2019-01_to_2019-04_sampled.csv
#
# 🔄 Processing Yellow Taxi batch 32:
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\yellow_tripdata_2019-05.parquet (10000 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\yellow_tripdata_2019-06.parquet (10000 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\yellow_tripdata_2019-07.parquet (10000 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\yellow_tripdata_2019-08.parquet (10000 rows kept)
# 💾 Saved sampled Yellow Taxi CSV file: D:/MSDS/Network Science/project/yellow_combined_data_sampled/yellow_tripdata_2019-05_to_2019-08_sampled.csv
#
# 🔄 Processing Yellow Taxi batch 33:
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\yellow_tripdata_2019-09.parquet (10000 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\yellow_tripdata_2019-10.parquet (10000 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\yellow_tripdata_2019-11.parquet (10000 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\yellow_tripdata_2019-12.parquet (10000 rows kept)
# 💾 Saved sampled Yellow Taxi CSV file: D:/MSDS/Network Science/project/yellow_combined_data_sampled/yellow_tripdata_2019-09_to_2019-12_sampled.csv
#
# 🔄 Processing Yellow Taxi batch 34:
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\yellow_tripdata_2020-01.parquet (10000 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\yellow_tripdata_2020-02.parquet (10000 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\yellow_tripdata_2020-03.parquet (10000 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\yellow_tripdata_2020-04.parquet (10000 rows kept)
# 💾 Saved sampled Yellow Taxi CSV file: D:/MSDS/Network Science/project/yellow_combined_data_sampled/yellow_tripdata_2020-01_to_2020-04_sampled.csv
#
# 🔄 Processing Yellow Taxi batch 35:
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\yellow_tripdata_2020-05.parquet (10000 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\yellow_tripdata_2020-06.parquet (10000 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\yellow_tripdata_2020-07.parquet (10000 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\yellow_tripdata_2020-08.parquet (10000 rows kept)
# 💾 Saved sampled Yellow Taxi CSV file: D:/MSDS/Network Science/project/yellow_combined_data_sampled/yellow_tripdata_2020-05_to_2020-08_sampled.csv
#
# 🔄 Processing Yellow Taxi batch 36:
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\yellow_tripdata_2020-09.parquet (10000 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\yellow_tripdata_2020-10.parquet (10000 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\yellow_tripdata_2020-11.parquet (10000 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\yellow_tripdata_2020-12.parquet (10000 rows kept)
# 💾 Saved sampled Yellow Taxi CSV file: D:/MSDS/Network Science/project/yellow_combined_data_sampled/yellow_tripdata_2020-09_to_2020-12_sampled.csv
#
# 🔄 Processing Yellow Taxi batch 37:
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\yellow_tripdata_2021-01.parquet (10000 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\yellow_tripdata_2021-02.parquet (10000 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\yellow_tripdata_2021-03.parquet (10000 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\yellow_tripdata_2021-04.parquet (10000 rows kept)
# 💾 Saved sampled Yellow Taxi CSV file: D:/MSDS/Network Science/project/yellow_combined_data_sampled/yellow_tripdata_2021-01_to_2021-04_sampled.csv
#
# 🔄 Processing Yellow Taxi batch 38:
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\yellow_tripdata_2021-05.parquet (10000 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\yellow_tripdata_2021-06.parquet (10000 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\yellow_tripdata_2021-07.parquet (10000 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\yellow_tripdata_2021-08.parquet (10000 rows kept)
# 💾 Saved sampled Yellow Taxi CSV file: D:/MSDS/Network Science/project/yellow_combined_data_sampled/yellow_tripdata_2021-05_to_2021-08_sampled.csv
#
# 🔄 Processing Yellow Taxi batch 39:
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\yellow_tripdata_2021-09.parquet (10000 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\yellow_tripdata_2021-10.parquet (10000 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\yellow_tripdata_2021-11.parquet (10000 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\yellow_tripdata_2021-12.parquet (10000 rows kept)
# 💾 Saved sampled Yellow Taxi CSV file: D:/MSDS/Network Science/project/yellow_combined_data_sampled/yellow_tripdata_2021-09_to_2021-12_sampled.csv
#
# 🔄 Processing Yellow Taxi batch 40:
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\yellow_tripdata_2022-01.parquet (10000 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\yellow_tripdata_2022-02.parquet (10000 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\yellow_tripdata_2022-03.parquet (10000 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\yellow_tripdata_2022-04.parquet (10000 rows kept)
# 💾 Saved sampled Yellow Taxi CSV file: D:/MSDS/Network Science/project/yellow_combined_data_sampled/yellow_tripdata_2022-01_to_2022-04_sampled.csv
#
# 🔄 Processing Yellow Taxi batch 41:
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\yellow_tripdata_2022-05.parquet (10000 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\yellow_tripdata_2022-06.parquet (10000 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\yellow_tripdata_2022-07.parquet (10000 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\yellow_tripdata_2022-08.parquet (10000 rows kept)
# 💾 Saved sampled Yellow Taxi CSV file: D:/MSDS/Network Science/project/yellow_combined_data_sampled/yellow_tripdata_2022-05_to_2022-08_sampled.csv
#
# 🔄 Processing Yellow Taxi batch 42:
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\yellow_tripdata_2022-09.parquet (10000 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\yellow_tripdata_2022-10.parquet (10000 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\yellow_tripdata_2022-11.parquet (10000 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\yellow_tripdata_2022-12.parquet (10000 rows kept)
# 💾 Saved sampled Yellow Taxi CSV file: D:/MSDS/Network Science/project/yellow_combined_data_sampled/yellow_tripdata_2022-09_to_2022-12_sampled.csv
#
# 🔄 Processing Yellow Taxi batch 43:
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\yellow_tripdata_2023-01.parquet (10000 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\yellow_tripdata_2023-02.parquet (10000 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\yellow_tripdata_2023-03.parquet (10000 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\yellow_tripdata_2023-04.parquet (10000 rows kept)
# 💾 Saved sampled Yellow Taxi CSV file: D:/MSDS/Network Science/project/yellow_combined_data_sampled/yellow_tripdata_2023-01_to_2023-04_sampled.csv
#
# 🔄 Processing Yellow Taxi batch 44:
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\yellow_tripdata_2023-05.parquet (10000 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\yellow_tripdata_2023-06.parquet (10000 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\yellow_tripdata_2023-07.parquet (10000 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\yellow_tripdata_2023-08.parquet (10000 rows kept)
# 💾 Saved sampled Yellow Taxi CSV file: D:/MSDS/Network Science/project/yellow_combined_data_sampled/yellow_tripdata_2023-05_to_2023-08_sampled.csv
#
# 🔄 Processing Yellow Taxi batch 45:
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\yellow_tripdata_2023-09.parquet (10000 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\yellow_tripdata_2023-10.parquet (10000 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\yellow_tripdata_2023-11.parquet (10000 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\yellow_tripdata_2023-12.parquet (10000 rows kept)
# 💾 Saved sampled Yellow Taxi CSV file: D:/MSDS/Network Science/project/yellow_combined_data_sampled/yellow_tripdata_2023-09_to_2023-12_sampled.csv
#
# 🔄 Processing Yellow Taxi batch 46:
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\yellow_tripdata_2024-01.parquet (10000 rows kept)
# 💾 Saved sampled Yellow Taxi CSV file: D:/MSDS/Network Science/project/yellow_combined_data_sampled/yellow_tripdata_2024-01_to_2024-01_sampled.csv

# %%
import pandas as pd
import glob
import os

# ✅ Make sure the output folder exists
os.makedirs('D:/MSDS/Network Science/project/fhv_combined_data_sampled/', exist_ok=True)

# Get all FHV files
file_list = sorted(glob.glob('D:/MSDS/Network Science/project/raw_data/fhv_tripdata_*.parquet'))

print(f"Found {len(file_list)} FHV files to process.")

# Group into batches of 4 files (for every 4 months)
batch_size = 4
batches = [file_list[i:i + batch_size] for i in range(0, len(file_list), batch_size)]

for batch_num, batch_files in enumerate(batches, start=1):
    print(f"\n🔄 Processing FHV batch {batch_num}:")
    batch_dfs = []
    
    for file in batch_files:
        try:
            # Extract year from filename
            file_name = os.path.basename(file)
            year_str = file_name.split('_')[2].split('-')[0]
            year = int(year_str)
            
            # Skip files from 2009–2014
            if year < 2015:
                print(f"⚠️ Skipping {file} because it is from {year} (before 2015).")
                continue
            
            needed_columns = ['dispatching_base_num', 'pickup_datetime', 'dropOff_datetime',
                              'PUlocationID', 'DOlocationID']
            
            # Read the full file
            df = pd.read_parquet(file)
            
            # Skip if PU/DO are not in the data
            if 'PUlocationID' not in df.columns or 'DOlocationID' not in df.columns:
                print(f"⚠️ Skipping {file} because it lacks PU/DO location IDs.")
                continue
            
            # Subset only needed columns
            available_columns = [col for col in needed_columns if col in df.columns]
            df = df[available_columns]
            
            # Random sample of 10,000 rows
            df_sampled = df.sample(n=10000, random_state=42)
            
            # Drop rows with missing PU/DO locations
            df_cleaned = df_sampled.dropna(subset=['PUlocationID', 'DOlocationID'])
            
            batch_dfs.append(df_cleaned)
            print(f" - Sampled and cleaned {file} ({df_cleaned.shape[0]} rows kept)")

        except Exception as e:
            print(f"❗ Error reading/cleaning {file}: {e}")
    
    if batch_dfs:
        # Combine the 4 files into one DataFrame
        combined_df = pd.concat(batch_dfs, ignore_index=True)
        
        # Extract the start and end month/year for naming
        start_file = os.path.basename(batch_files[0])
        end_file = os.path.basename(batch_files[-1])
        
        start_period = start_file.replace('fhv_tripdata_', '').replace('.parquet', '')
        end_period = end_file.replace('fhv_tripdata_', '').replace('.parquet', '')
        
        # Save combined CSV file
        output_file = f'D:/MSDS/Network Science/project/fhv_combined_data_sampled/fhv_tripdata_{start_period}_to_{end_period}_sampled.csv'
        
        combined_df.to_csv(output_file, index=False)
        print(f"💾 Saved sampled FHV CSV file: {output_file}")
    else:
        print(f"⚠️ No data to save for FHV batch {batch_num}.")
# Out:
# Found 109 FHV files to process.
#
# 🔄 Processing FHV batch 1:
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\fhv_tripdata_2015-01.parquet (11 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\fhv_tripdata_2015-02.parquet (106 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\fhv_tripdata_2015-03.parquet (131 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\fhv_tripdata_2015-04.parquet (471 rows kept)
# 💾 Saved sampled FHV CSV file: D:/MSDS/Network Science/project/fhv_combined_data_sampled/fhv_tripdata_2015-01_to_2015-04_sampled.csv
#
# 🔄 Processing FHV batch 2:
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\fhv_tripdata_2015-05.parquet (324 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\fhv_tripdata_2015-06.parquet (28 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\fhv_tripdata_2015-07.parquet (19 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\fhv_tripdata_2015-08.parquet (199 rows kept)
# 💾 Saved sampled FHV CSV file: D:/MSDS/Network Science/project/fhv_combined_data_sampled/fhv_tripdata_2015-05_to_2015-08_sampled.csv
#
# 🔄 Processing FHV batch 3:
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\fhv_tripdata_2015-09.parquet (138 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\fhv_tripdata_2015-10.parquet (226 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\fhv_tripdata_2015-11.parquet (265 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\fhv_tripdata_2015-12.parquet (277 rows kept)
# 💾 Saved sampled FHV CSV file: D:/MSDS/Network Science/project/fhv_combined_data_sampled/fhv_tripdata_2015-09_to_2015-12_sampled.csv
#
# 🔄 Processing FHV batch 4:
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\fhv_tripdata_2016-01.parquet (147 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\fhv_tripdata_2016-02.parquet (137 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\fhv_tripdata_2016-03.parquet (141 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\fhv_tripdata_2016-04.parquet (159 rows kept)
# 💾 Saved sampled FHV CSV file: D:/MSDS/Network Science/project/fhv_combined_data_sampled/fhv_tripdata_2016-01_to_2016-04_sampled.csv
#
# 🔄 Processing FHV batch 5:
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\fhv_tripdata_2016-05.parquet (169 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\fhv_tripdata_2016-06.parquet (162 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\fhv_tripdata_2016-07.parquet (166 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\fhv_tripdata_2016-08.parquet (127 rows kept)
# 💾 Saved sampled FHV CSV file: D:/MSDS/Network Science/project/fhv_combined_data_sampled/fhv_tripdata_2016-05_to_2016-08_sampled.csv
#
# 🔄 Processing FHV batch 6:
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\fhv_tripdata_2016-09.parquet (95 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\fhv_tripdata_2016-10.parquet (73 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\fhv_tripdata_2016-11.parquet (94 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\fhv_tripdata_2016-12.parquet (100 rows kept)
# 💾 Saved sampled FHV CSV file: D:/MSDS/Network Science/project/fhv_combined_data_sampled/fhv_tripdata_2016-09_to_2016-12_sampled.csv
#
# 🔄 Processing FHV batch 7:
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\fhv_tripdata_2017-01.parquet (64 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\fhv_tripdata_2017-02.parquet (82 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\fhv_tripdata_2017-03.parquet (92 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\fhv_tripdata_2017-04.parquet (66 rows kept)
# 💾 Saved sampled FHV CSV file: D:/MSDS/Network Science/project/fhv_combined_data_sampled/fhv_tripdata_2017-01_to_2017-04_sampled.csv
#
# 🔄 Processing FHV batch 8:
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\fhv_tripdata_2017-05.parquet (69 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\fhv_tripdata_2017-06.parquet (7808 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\fhv_tripdata_2017-07.parquet (7998 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\fhv_tripdata_2017-08.parquet (7949 rows kept)
# 💾 Saved sampled FHV CSV file: D:/MSDS/Network Science/project/fhv_combined_data_sampled/fhv_tripdata_2017-05_to_2017-08_sampled.csv
#
# 🔄 Processing FHV batch 9:
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\fhv_tripdata_2017-09.parquet (7934 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\fhv_tripdata_2017-10.parquet (8058 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\fhv_tripdata_2017-11.parquet (8153 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\fhv_tripdata_2017-12.parquet (8123 rows kept)
# 💾 Saved sampled FHV CSV file: D:/MSDS/Network Science/project/fhv_combined_data_sampled/fhv_tripdata_2017-09_to_2017-12_sampled.csv
#
# 🔄 Processing FHV batch 10:
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\fhv_tripdata_2018-01.parquet (8176 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\fhv_tripdata_2018-02.parquet (8196 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\fhv_tripdata_2018-03.parquet (8388 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\fhv_tripdata_2018-04.parquet (8500 rows kept)
# 💾 Saved sampled FHV CSV file: D:/MSDS/Network Science/project/fhv_combined_data_sampled/fhv_tripdata_2018-01_to_2018-04_sampled.csv
#
# 🔄 Processing FHV batch 11:
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\fhv_tripdata_2018-05.parquet (8572 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\fhv_tripdata_2018-06.parquet (8512 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\fhv_tripdata_2018-07.parquet (8690 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\fhv_tripdata_2018-08.parquet (8688 rows kept)
# 💾 Saved sampled FHV CSV file: D:/MSDS/Network Science/project/fhv_combined_data_sampled/fhv_tripdata_2018-05_to_2018-08_sampled.csv
#
# 🔄 Processing FHV batch 12:
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\fhv_tripdata_2018-09.parquet (8718 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\fhv_tripdata_2018-10.parquet (8682 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\fhv_tripdata_2018-11.parquet (8761 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\fhv_tripdata_2018-12.parquet (8690 rows kept)
# 💾 Saved sampled FHV CSV file: D:/MSDS/Network Science/project/fhv_combined_data_sampled/fhv_tripdata_2018-09_to_2018-12_sampled.csv
#
# 🔄 Processing FHV batch 13:
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\fhv_tripdata_2019-01.parquet (9198 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\fhv_tripdata_2019-02.parquet (10000 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\fhv_tripdata_2019-03.parquet (9991 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\fhv_tripdata_2019-04.parquet (9982 rows kept)
# 💾 Saved sampled FHV CSV file: D:/MSDS/Network Science/project/fhv_combined_data_sampled/fhv_tripdata_2019-01_to_2019-04_sampled.csv
#
# 🔄 Processing FHV batch 14:
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\fhv_tripdata_2019-05.parquet (10000 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\fhv_tripdata_2019-06.parquet (10000 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\fhv_tripdata_2019-07.parquet (9951 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\fhv_tripdata_2019-08.parquet (9692 rows kept)
# 💾 Saved sampled FHV CSV file: D:/MSDS/Network Science/project/fhv_combined_data_sampled/fhv_tripdata_2019-05_to_2019-08_sampled.csv
#
# 🔄 Processing FHV batch 15:
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\fhv_tripdata_2019-09.parquet (9391 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\fhv_tripdata_2019-10.parquet (9948 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\fhv_tripdata_2019-11.parquet (9965 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\fhv_tripdata_2019-12.parquet (9797 rows kept)
# 💾 Saved sampled FHV CSV file: D:/MSDS/Network Science/project/fhv_combined_data_sampled/fhv_tripdata_2019-09_to_2019-12_sampled.csv
#
# 🔄 Processing FHV batch 16:
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\fhv_tripdata_2020-01.parquet (9746 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\fhv_tripdata_2020-02.parquet (8831 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\fhv_tripdata_2020-03.parquet (8786 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\fhv_tripdata_2020-04.parquet (6978 rows kept)
# 💾 Saved sampled FHV CSV file: D:/MSDS/Network Science/project/fhv_combined_data_sampled/fhv_tripdata_2020-01_to_2020-04_sampled.csv
#
# 🔄 Processing FHV batch 17:
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\fhv_tripdata_2020-05.parquet (9970 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\fhv_tripdata_2020-06.parquet (9997 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\fhv_tripdata_2020-07.parquet (9997 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\fhv_tripdata_2020-08.parquet (9968 rows kept)
# 💾 Saved sampled FHV CSV file: D:/MSDS/Network Science/project/fhv_combined_data_sampled/fhv_tripdata_2020-05_to_2020-08_sampled.csv
#
# 🔄 Processing FHV batch 18:
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\fhv_tripdata_2020-09.parquet (9999 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\fhv_tripdata_2020-10.parquet (1985 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\fhv_tripdata_2020-11.parquet (1848 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\fhv_tripdata_2020-12.parquet (1466 rows kept)
# 💾 Saved sampled FHV CSV file: D:/MSDS/Network Science/project/fhv_combined_data_sampled/fhv_tripdata_2020-09_to_2020-12_sampled.csv
#
# 🔄 Processing FHV batch 19:
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\fhv_tripdata_2021-01.parquet (1569 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\fhv_tripdata_2021-02.parquet (1325 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\fhv_tripdata_2021-03.parquet (1515 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\fhv_tripdata_2021-04.parquet (1612 rows kept)
# 💾 Saved sampled FHV CSV file: D:/MSDS/Network Science/project/fhv_combined_data_sampled/fhv_tripdata_2021-01_to_2021-04_sampled.csv
#
# 🔄 Processing FHV batch 20:
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\fhv_tripdata_2021-05.parquet (1651 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\fhv_tripdata_2021-06.parquet (1606 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\fhv_tripdata_2021-07.parquet (1582 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\fhv_tripdata_2021-08.parquet (1683 rows kept)
# 💾 Saved sampled FHV CSV file: D:/MSDS/Network Science/project/fhv_combined_data_sampled/fhv_tripdata_2021-05_to_2021-08_sampled.csv
#
# 🔄 Processing FHV batch 21:
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\fhv_tripdata_2021-09.parquet (1781 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\fhv_tripdata_2021-10.parquet (1788 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\fhv_tripdata_2021-11.parquet (1780 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\fhv_tripdata_2021-12.parquet (2422 rows kept)
# 💾 Saved sampled FHV CSV file: D:/MSDS/Network Science/project/fhv_combined_data_sampled/fhv_tripdata_2021-09_to_2021-12_sampled.csv
#
# 🔄 Processing FHV batch 22:
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\fhv_tripdata_2022-01.parquet (2210 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\fhv_tripdata_2022-02.parquet (2152 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\fhv_tripdata_2022-03.parquet (2220 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\fhv_tripdata_2022-04.parquet (2502 rows kept)
# 💾 Saved sampled FHV CSV file: D:/MSDS/Network Science/project/fhv_combined_data_sampled/fhv_tripdata_2022-01_to_2022-04_sampled.csv
#
# 🔄 Processing FHV batch 23:
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\fhv_tripdata_2022-05.parquet (2478 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\fhv_tripdata_2022-06.parquet (2703 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\fhv_tripdata_2022-07.parquet (2513 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\fhv_tripdata_2022-08.parquet (2371 rows kept)
# 💾 Saved sampled FHV CSV file: D:/MSDS/Network Science/project/fhv_combined_data_sampled/fhv_tripdata_2022-05_to_2022-08_sampled.csv
#
# 🔄 Processing FHV batch 24:
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\fhv_tripdata_2022-09.parquet (2306 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\fhv_tripdata_2022-10.parquet (2277 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\fhv_tripdata_2022-11.parquet (2000 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\fhv_tripdata_2022-12.parquet (2061 rows kept)
# 💾 Saved sampled FHV CSV file: D:/MSDS/Network Science/project/fhv_combined_data_sampled/fhv_tripdata_2022-09_to_2022-12_sampled.csv
#
# 🔄 Processing FHV batch 25:
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\fhv_tripdata_2023-01.parquet (2156 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\fhv_tripdata_2023-02.parquet (2061 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\fhv_tripdata_2023-03.parquet (2124 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\fhv_tripdata_2023-04.parquet (2095 rows kept)
# 💾 Saved sampled FHV CSV file: D:/MSDS/Network Science/project/fhv_combined_data_sampled/fhv_tripdata_2023-01_to_2023-04_sampled.csv
#
# 🔄 Processing FHV batch 26:
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\fhv_tripdata_2023-05.parquet (2304 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\fhv_tripdata_2023-06.parquet (2388 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\fhv_tripdata_2023-07.parquet (2305 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\fhv_tripdata_2023-08.parquet (2531 rows kept)
# 💾 Saved sampled FHV CSV file: D:/MSDS/Network Science/project/fhv_combined_data_sampled/fhv_tripdata_2023-05_to_2023-08_sampled.csv
#
# 🔄 Processing FHV batch 27:
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\fhv_tripdata_2023-09.parquet (2638 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\fhv_tripdata_2023-10.parquet (2404 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\fhv_tripdata_2023-11.parquet (1429 rows kept)
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\fhv_tripdata_2023-12.parquet (1693 rows kept)
# 💾 Saved sampled FHV CSV file: D:/MSDS/Network Science/project/fhv_combined_data_sampled/fhv_tripdata_2023-09_to_2023-12_sampled.csv
#
# 🔄 Processing FHV batch 28:
#  - Sampled and cleaned D:/MSDS/Network Science/project/raw_data\fhv_tripdata_2024-01.parquet (2032 rows kept)
# 💾 Saved sampled FHV CSV file: D:/MSDS/Network Science/project/fhv_combined_data_sampled/fhv_tripdata_2024-01_to_2024-01_sampled.csv
